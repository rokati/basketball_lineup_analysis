# %% [markdown]
# # Prequisite

# %%
# !pip install --no-cache-dir --force-reinstall numpy==1.26.4 pandas==2.2.2
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 73.7 MB/s eta 0:00:00
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting python-dateutil>=2.8.2 (from pandas==2.2.2)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.2.2)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.2.2)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 164.8 MB/s eta 0:00:00
# Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 68.7 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 164.7 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 180.0 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 214.9 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# Successfully installed numpy-1.26.4 pandas-2.2.2 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2

# %%
# !pip install nba_api
# Out:
# Collecting nba_api
#   Downloading nba_api-1.9.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from nba_api) (1.26.4)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from nba_api) (2.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from nba_api) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->nba_api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->nba_api) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->nba_api) (1.17.0)
# Downloading nba_api-1.9.0-py3-none-any.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.9/284.9 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: nba_api
# Successfully installed nba_api-1.9.0

# %%
import pandas as pd
import time
from tqdm import tqdm
import numpy as np
from collections import defaultdict
from nba_api.stats.endpoints import (PlayByPlayV2,
                                     BoxScoreSummaryV2,
                                     BoxScoreTraditionalV2,
                                     LeagueGameFinder)

# %% [markdown]
# # Pbp data Lineup events

# %%
game_id = '0022300001'

# %%
pbp = PlayByPlayV2(game_id=game_id).get_data_frames()[0] # for events
box = BoxScoreTraditionalV2(game_id=game_id).get_data_frames()[0] # for starter players
summary = BoxScoreSummaryV2(game_id=game_id).get_data_frames()[0] # for home and away team ids

home_team_id = summary['HOME_TEAM_ID'][0]
away_team_id = summary['VISITOR_TEAM_ID'][0]

starters_df = box[box['START_POSITION'] != '']
starters_by_team = starters_df.groupby('TEAM_ID')['PLAYER_NAME'].apply(list).to_dict()

current_lineups = {
    home_team_id: starters_by_team[home_team_id][:],
    away_team_id: starters_by_team[away_team_id][:]
}

# %% [markdown]
# We’ve got:
#
# - Clean PBP DataFrame
# - Clear home/away team IDs
# - Initial 5-man lineup per team

# %%
important_event_types = list(range(1, 14))  # all 13 official event types

lineup_timeline = []

for _, row in pbp.iterrows():
    event_type = row['EVENTMSGTYPE']
    home_desc = str(row['HOMEDESCRIPTION']) if pd.notna(row['HOMEDESCRIPTION']) else ''
    away_desc = str(row['VISITORDESCRIPTION']) if pd.notna(row['VISITORDESCRIPTION']) else ''

    # Handle substitutions
    if event_type == 8:
        out_player = row['PLAYER1_NAME']
        in_player = row['PLAYER2_NAME']
        team_id = row['PLAYER1_TEAM_ID'] if pd.notna(row['PLAYER1_TEAM_ID']) else row['PLAYER2_TEAM_ID']
        team_id = int(team_id) if pd.notna(team_id) else None

        if team_id in current_lineups:
            if out_player in current_lineups[team_id]:
                current_lineups[team_id].remove(out_player)
            if in_player not in current_lineups[team_id]:
                current_lineups[team_id].append(in_player)

    # Record all important events with lineup snapshot
    if event_type in important_event_types:
        lineup_timeline.append({
            'EVENTNUM': row['EVENTNUM'],
            'PERIOD': row['PERIOD'],
            'TIME': row['PCTIMESTRING'],
            'EVENT_TYPE': event_type,
            'SCORE': row['SCORE'],
            'HOME_DESCRIPTION': home_desc,
            'AWAY_DESCRIPTION': away_desc,
            'HOME_LINEUP': current_lineups[home_team_id][:],
            'AWAY_LINEUP': current_lineups[away_team_id][:],
            'PLAYER1_NAME': row['PLAYER1_NAME'],
            'PLAYER2_NAME': row['PLAYER2_NAME'],
            'PLAYER3_NAME': row['PLAYER3_NAME']
        })

lineup_df = pd.DataFrame(lineup_timeline)

# %%
# What kind of 2PTS shot names exist
result_df = lineup_df[lineup_df['SCORE'].notna()][['SCORE', 'HOME_DESCRIPTION', 'AWAY_DESCRIPTION']]

proba_df = result_df[
    ~result_df['HOME_DESCRIPTION'].str.contains('|'.join([ 'Fadeaway','3PT','Free Throw', 'Dunk', 'Layup', 'Jump Shot', 'Hook Shot']), case=False, na=False) &
    ~result_df['AWAY_DESCRIPTION'].str.contains('|'.join(['Fadeaway', '3PT','Free Throw','Dunk', 'Layup', 'Jump Shot', 'Hook Shot']), case=False, na=False)
]
proba_df
# Out:
#          SCORE HOME_DESCRIPTION AWAY_DESCRIPTION
# 116    26 - 36
# 117    26 - 36
# 235    53 - 70
# 236    53 - 70
# 340    87 - 88
# 341    87 - 88
# 472  116 - 121

# %% [markdown]
# # Constructing lineup_segments
# Stretches of continuous play with the same home and away lineups.
# For each:
#   - Count team-level stats (points, assists, TOs, etc.)
#   - Count player-level stats for only those on the floor
#   - End the segment when either team makes a substitution

# %%
from collections import defaultdict

lineup_segments = []
segment = None
prev_home = None
prev_away = None
last_shot_team = None  # Used to infer rebound type (off vs def)
SKIP_KEYWORDS = [
    'SUB',
    'Jump Ball',
    'Delay',
    'Offensive',
    'Timeout',
    'Rebound'
]

# Loop through every event in the play-by-play lineup_df
for _, row in lineup_df.iterrows():
    home_lineup = tuple(sorted(row['HOME_LINEUP']))
    away_lineup = tuple(sorted(row['AWAY_LINEUP']))

    # ---- 1. START NEW SEGMENT IF LINEUPS CHANGED ----
    if segment is None or home_lineup != prev_home or away_lineup != prev_away:
        if segment:
            segment['end_event'] = row['EVENTNUM']
            segment['end_time'] = row['TIME']
            lineup_segments.append(segment)

        segment = {
            'home_lineup': home_lineup,
            'away_lineup': away_lineup,
            'start_event': row['EVENTNUM'],
            'start_time': row['TIME'],
            'period': row['PERIOD'],
            'team_stats': {
                'home': defaultdict(int),
                'away': defaultdict(int)
            },
            'player_stats': defaultdict(lambda: defaultdict(int)),
            'events': []
        }

        prev_home = home_lineup
        prev_away = away_lineup

    # ---- 2. LOG THE EVENT ----
    segment['events'].append({
        'EVENTNUM': row['EVENTNUM'],
        'TIME': row['TIME'],
        'HOME_DESCRIPTION': row['HOME_DESCRIPTION'],
        'AWAY_DESCRIPTION': row['AWAY_DESCRIPTION']
    })

    # ---- 3. PROCESS HOME AND AWAY DESCRIPTIONS ----
    for team_side, desc in [('home', row['HOME_DESCRIPTION']), ('away', row['AWAY_DESCRIPTION'])]:
        if not desc or any(skip_word in desc for skip_word in SKIP_KEYWORDS):
            continue

        lineup = home_lineup if team_side == 'home' else away_lineup
        players_on_court = set(lineup)

        # Helper to increment team & player stats
        def inc(stat, players, value=1):
            segment['team_stats'][team_side][stat] += value
            for p in players:
                if p in players_on_court:
                    segment['player_stats'][p][stat] += value

        # Get involved players from row (if names are not null and on court)
        players = []
        for p in [row['PLAYER1_NAME'], row['PLAYER2_NAME'], row['PLAYER3_NAME']]:
            if isinstance(p, str) and p in players_on_court:
                players.append(p)

        # ---- 4. ACTION DETECTION ----

        # --- Shots ---
        if '3PT' in desc and 'MISS' not in desc:
            inc('3pt_made', [row['PLAYER1_NAME']])
            inc('points', [row['PLAYER1_NAME']], value=3)
        elif 'Free Throw' in desc and 'MISS' not in desc:
            inc('ft_made', [row['PLAYER1_NAME']])
            inc('points', [row['PLAYER1_NAME']])
        elif 'MISS' not in desc and any(kw in desc for kw in ['Fadeaway', 'Dunk', 'Layup', 'Jump Shot', 'Hook Shot']):
            inc('2pt_made', [row['PLAYER1_NAME']])
            inc('points', [row['PLAYER1_NAME']], value=2)
        elif 'MISS' in desc:
            last_shot_team = team_side

        if 'AST' in desc:
            inc('assists', [row['PLAYER2_NAME']])
        if 'Turnover' in desc:
            inc('turnovers', [row['PLAYER1_NAME']])
        if 'STL' in desc:
            inc('steals', [row['PLAYER2_NAME']])
        if 'BLK' in desc:
            inc('blocks', [row['PLAYER2_NAME']])
        if '.FOUL' in desc:
            inc('fouls', [row['PLAYER1_NAME']])

        # --- Rebounds ---
        if 'REBOUND' in desc:
            rebound_team = team_side
            rebounder = row['PLAYER1_NAME']
            if last_shot_team:
                if rebound_team == last_shot_team:
                    inc('off_rebounds', [rebounder])
                else:
                    inc('def_rebounds', [rebounder])
            last_shot_team = None  # Reset after rebound

# ---- 5. FLUSH FINAL SEGMENT ----
if segment:
    segment['end_event'] = row['EVENTNUM']
    segment['end_time'] = row['TIME']
    lineup_segments.append(segment)

# %% [markdown]
# # lineup_vs_lineup_df
# **Team stats per segment**<br>
# Each row represents:
#  - One continuous period where the same home and away lineups were on the floor
#  - Aggregated team-level stats (points, 3pt, rebounds, assists, TOs, etc.)

# %%
lineup_vs_lineup_data = []

for seg in lineup_segments:
    row = {
        'period': seg['period'],
        'start_event': seg['start_event'],
        'end_event': seg['end_event'],
        'start_time': seg['start_time'],
        'end_time': seg['end_time'],
        'home_lineup': seg['home_lineup'],
        'away_lineup': seg['away_lineup'],
    }

    # Flatten team stats into prefixed keys
    for team in ['home', 'away']:
        for stat, value in seg['team_stats'][team].items():
            row[f'{team}_{stat}'] = value

    lineup_vs_lineup_data.append(row)

lineup_vs_lineup_df = pd.DataFrame(lineup_vs_lineup_data)

# %%
lineup_vs_lineup_df
# Out:
#     period  start_event  end_event start_time end_time  \
# 0        1            2         69      12:00     6:43
# 1        1           69         78       6:43     6:22
# 2        1           78         92       6:22     5:15
# 3        1           92         93       5:15     5:15
# 4        1           93        103       5:15     4:46
# 5        1          103        104       4:46     4:46
# 6        1          104        105       4:46     4:46
# 7        1          105        120       4:46     3:27
# 8        1          120        121       3:27     3:27
# 9        1          121        124       3:27     3:27
# 10       1          124        154       3:27     1:16
# 11       1          154        172       1:16     0:03
# 12       1          172        204       0:03    10:39
# 13       2          204        210      10:39    10:30
# 14       2          210        228      10:30     8:49
# 15       2          228        230       8:49     8:49
# 16       2          230        264       8:49     5:41
# 17       2          264        265       5:41     5:41
# 18       2          265        266       5:41     5:41
# 19       2          266        277       5:41     5:41
# 20       2          277        278       5:41     5:41
# 21       2          278        302       5:41     2:53
# 22       2          302        303       2:53     2:53
# 23       2          303        304       2:53     2:53
# 24       2          304        336       2:53     0:27
# 25       2          336        411       0:27     6:38
# 26       3          411        412       6:38     6:38
# 27       3          412        421       6:38     6:19
# 28       3          421        447       6:19     4:25
# 29       3          447        448       4:25     4:25
# 30       3          448        461       4:25     2:48
# 31       3          461        468       2:48     2:09
# 32       3          468        477       2:09     1:35
# 33       3          477        518       1:35     9:45
# 34       4          518        526       9:45     9:22
# 35       4          526        527       9:22     9:22
# 36       4          527        528       9:22     9:22
# 37       4          528        541       9:22     8:15
# 38       4          541        555       8:15     6:58
# 39       4          555        565       6:58     6:21
# 40       4          565        577       6:21     4:56
# 41       4          577        586       4:56     4:08
# 42       4          586        606       4:08     2:16
# 43       4          606        630       2:16     0:16
# 44       4          630        631       0:16     0:16
# 45       4          631        644       0:16     0:07
# 46       4          644        645       0:07     0:07
# 47       4          645        649       0:07     0:07
# 48       4          649        656       0:07     0:07
# 49       4          656        657       0:07     0:07
# 50       4          657        658       0:07     0:07
# 51       4          658        667       0:07     0:02
# 52       4          667        668       0:02     0:02
# 53       4          668        669       0:02     0:02
# 54       4          669        675       0:02     0:02
# 55       4          675        676       0:02     0:02
# 56       4          676        677       0:02     0:02
# 57       4          677        684       0:02     0:01
# 58       4          684        685       0:01     0:01
# 59       4          685        686       0:01     0:01
# 60       4          686        693       0:01     0:00
#
#                                           home_lineup  \
# 0   (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 1   (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 2   (Bruce Brown, Buddy Hield, Myles Turner, Obi T...
# 3   (Andrew Nembhard, Buddy Hield, Myles Turner, O...
# 4   (Andrew Nembhard, Buddy Hield, Jalen Smith, Ob...
# 5   (Aaron Nesmith, Andrew Nembhard, Buddy Hield, ...
# 6   (Aaron Nesmith, Andrew Nembhard, Buddy Hield, ...
# 7   (Aaron Nesmith, Andrew Nembhard, Buddy Hield, ...
# 8   (Aaron Nesmith, Andrew Nembhard, Bennedict Mat...
# 9   (Aaron Nesmith, Andrew Nembhard, Bennedict Mat...
# 10  (Aaron Nesmith, Andrew Nembhard, Bennedict Mat...
# 11  (Aaron Nesmith, Andrew Nembhard, Bennedict Mat...
# 12  (Aaron Nesmith, Andrew Nembhard, Bennedict Mat...
# 13  (Aaron Nesmith, Andrew Nembhard, Bennedict Mat...
# 14  (Aaron Nesmith, Andrew Nembhard, Bennedict Mat...
# 15  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 16  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 17  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 18  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 19  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 20  (Aaron Nesmith, Bruce Brown, Myles Turner, Obi...
# 21  (Bruce Brown, Buddy Hield, Myles Turner, Obi T...
# 22  (Bruce Brown, Buddy Hield, Myles Turner, Obi T...
# 23  (Bruce Brown, Buddy Hield, Myles Turner, Obi T...
# 24  (Bruce Brown, Buddy Hield, Myles Turner, Obi T...
# 25  (Bruce Brown, Buddy Hield, Myles Turner, Obi T...
# 26  (Andrew Nembhard, Buddy Hield, Myles Turner, O...
# 27  (Andrew Nembhard, Buddy Hield, Myles Turner, O...
# 28  (Andrew Nembhard, Buddy Hield, Jalen Smith, Ob...
# 29  (Andrew Nembhard, Bruce Brown, Buddy Hield, Ja...
# 30  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 31  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 32  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 33  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 34  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 35  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 36  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 37  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 38  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 39  (Aaron Nesmith, Bennedict Mathurin, Bruce Brow...
# 40  (Aaron Nesmith, Bruce Brown, Buddy Hield, Myle...
# 41  (Aaron Nesmith, Bruce Brown, Buddy Hield, Myle...
# 42  (Aaron Nesmith, Bruce Brown, Buddy Hield, Myle...
# 43  (Aaron Nesmith, Bruce Brown, Buddy Hield, Myle...
# 44  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 45  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 46  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 47  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 48  (Andrew Nembhard, Bruce Brown, Buddy Hield, My...
# 49  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 50  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 51  (Aaron Nesmith, Andrew Nembhard, Bruce Brown, ...
# 52  (Aaron Nesmith, Bruce Brown, Jalen Smith, Myle...
# 53  (Aaron Nesmith, Bruce Brown, Jalen Smith, Myle...
# 54  (Aaron Nesmith, Bruce Brown, Jalen Smith, Myle...
# 55  (Bruce Brown, Buddy Hield, Jalen Smith, Myles ...
# 56  (Bruce Brown, Buddy Hield, Jalen Smith, Myles ...
# 57  (Bruce Brown, Buddy Hield, Jalen Smith, Myles ...
# 58  (Aaron Nesmith, Bruce Brown, Jalen Smith, Myle...
# 59  (Aaron Nesmith, Bruce Brown, Jalen Smith, Myle...
# 60  (Aaron Nesmith, Bruce Brown, Jalen Smith, Myle...
#
#                                           away_lineup  home_2pt_made  \
# 0   (Darius Garland, Donovan Mitchell, Evan Mobley...            3.0
# 1   (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 2   (Darius Garland, Donovan Mitchell, Evan Mobley...            1.0
# 3   (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 4   (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 5   (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 6   (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 7   (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 8   (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 9   (Caris LeVert, Darius Garland, Evan Mobley, Ge...            NaN
# 10  (Caris LeVert, Darius Garland, Georges Niang, ...            3.0
# 11  (Caris LeVert, Darius Garland, Dean Wade, Geor...            2.0
# 12  (Caris LeVert, Darius Garland, Dean Wade, Geor...            NaN
# 13  (Caris LeVert, Dean Wade, Donovan Mitchell, Ge...            NaN
# 14  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            1.0
# 15  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 16  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            1.0
# 17  (Donovan Mitchell, Evan Mobley, Georges Niang,...            NaN
# 18  (Darius Garland, Donovan Mitchell, Georges Nia...            NaN
# 19  (Darius Garland, Donovan Mitchell, Isaac Okoro...            NaN
# 20  (Darius Garland, Donovan Mitchell, Isaac Okoro...            NaN
# 21  (Darius Garland, Donovan Mitchell, Isaac Okoro...            2.0
# 22  (Darius Garland, Donovan Mitchell, Georges Nia...            NaN
# 23  (Caris LeVert, Donovan Mitchell, Georges Niang...            NaN
# 24  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            3.0
# 25  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            4.0
# 26  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 27  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 28  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 29  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 30  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            1.0
# 31  (Caris LeVert, Darius Garland, Evan Mobley, Ge...            NaN
# 32  (Caris LeVert, Darius Garland, Georges Niang, ...            NaN
# 33  (Caris LeVert, Darius Garland, Georges Niang, ...            5.0
# 34  (Caris LeVert, Darius Garland, Evan Mobley, Ge...            NaN
# 35  (Caris LeVert, Darius Garland, Evan Mobley, Ge...            NaN
# 36  (Caris LeVert, Darius Garland, Evan Mobley, Ge...            NaN
# 37  (Caris LeVert, Darius Garland, Evan Mobley, Ge...            NaN
# 38  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 39  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 40  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            2.0
# 41  (Caris LeVert, Darius Garland, Donovan Mitchel...            1.0
# 42  (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 43  (Caris LeVert, Darius Garland, Donovan Mitchel...            1.0
# 44  (Caris LeVert, Darius Garland, Donovan Mitchel...            NaN
# 45  (Caris LeVert, Darius Garland, Donovan Mitchel...            NaN
# 46  (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 47  (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 48  (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 49  (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 50  (Darius Garland, Donovan Mitchell, Evan Mobley...            NaN
# 51  (Caris LeVert, Darius Garland, Donovan Mitchel...            NaN
# 52  (Caris LeVert, Darius Garland, Donovan Mitchel...            NaN
# 53  (Caris LeVert, Darius Garland, Donovan Mitchel...            NaN
# 54  (Caris LeVert, Donovan Mitchell, Jarrett Allen...            NaN
# 55  (Caris LeVert, Donovan Mitchell, Jarrett Allen...            NaN
# 56  (Caris LeVert, Donovan Mitchell, Isaac Okoro, ...            NaN
# 57  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 58  (Caris LeVert, Donovan Mitchell, Evan Mobley, ...            NaN
# 59  (Caris LeVert, Darius Garland, Donovan Mitchel...            NaN
# 60  (Caris LeVert, Darius Garland, Donovan Mitchel...            NaN
#
#     home_points  home_assists  home_def_rebounds  home_off_rebounds  \
# 0          17.0           5.0                5.0                2.0
# 1           NaN           NaN                NaN                NaN
# 2           5.0           1.0                1.0                NaN
# 3           NaN           NaN                NaN                NaN
# 4           NaN           NaN                NaN                NaN
# 5           NaN           NaN                NaN                NaN
# 6           NaN           NaN                NaN                NaN
# 7           3.0           1.0                NaN                NaN
# 8           NaN           NaN                NaN                NaN
# 9           NaN           NaN                NaN                NaN
# 10          6.0           3.0                2.0                NaN
# 11          4.0           2.0                1.0                NaN
# 12          6.0           1.0                3.0                NaN
# 13          NaN           NaN                NaN                NaN
# 14          2.0           NaN                NaN                NaN
# 15          NaN           NaN                NaN                NaN
# 16          5.0           2.0                3.0                NaN
# 17          NaN           NaN                NaN                NaN
# 18          NaN           NaN                NaN                NaN
# 19          NaN           NaN                NaN                NaN
# 20          NaN           NaN                NaN                NaN
# 21         10.0           2.0                4.0                1.0
# 22          NaN           NaN                NaN                NaN
# 23          NaN           NaN                NaN                NaN
# 24          9.0           3.0                1.0                NaN
# 25          9.0           NaN                4.0                1.0
# 26          NaN           NaN                NaN                NaN
# 27          NaN           NaN                NaN                NaN
# 28          3.0           1.0                NaN                NaN
# 29          NaN           NaN                NaN                NaN
# 30          5.0           1.0                NaN                1.0
# 31          NaN           NaN                NaN                NaN
# 32          NaN           NaN                1.0                NaN
# 33         10.0           2.0                2.0                2.0
# 34          NaN           NaN                NaN                NaN
# 35          NaN           NaN                NaN                NaN
# 36          NaN           NaN                NaN                NaN
# 37          3.0           1.0                1.0                NaN
# 38          3.0           1.0                NaN                NaN
# 39          1.0           NaN                NaN                NaN
# 40          7.0           NaN                2.0                NaN
# 41          2.0           1.0                1.0                NaN
# 42          3.0           1.0                NaN                NaN
# 43          4.0           NaN                1.0                NaN
# 44          NaN           NaN                NaN                NaN
# 45          NaN           NaN                1.0                NaN
# 46          NaN           NaN                NaN                NaN
# 47          NaN           NaN                NaN                NaN
# 48          1.0           NaN                NaN                NaN
# 49          NaN           NaN                NaN                NaN
# 50          NaN           NaN                NaN                NaN
# 51          1.0           NaN                NaN                NaN
# 52          NaN           NaN                NaN                NaN
# 53          NaN           NaN                NaN                NaN
# 54          NaN           NaN                NaN                NaN
# 55          NaN           NaN                NaN                NaN
# 56          NaN           NaN                NaN                NaN
# 57          1.0           NaN                NaN                NaN
# 58          NaN           NaN                NaN                NaN
# 59          NaN           NaN                NaN                NaN
# 60          1.0           NaN                NaN                NaN
#
#     home_3pt_made  home_turnovers  home_steals  home_ft_made  away_2pt_made  \
# 0             3.0             2.0          1.0           2.0            4.0
# 1             NaN             NaN          NaN           NaN            NaN
# 2             1.0             1.0          NaN           NaN            1.0
# 3             NaN             NaN          NaN           NaN            NaN
# 4             NaN             NaN          NaN           NaN            1.0
# 5             NaN             NaN          NaN           NaN            NaN
# 6             NaN             NaN          NaN           NaN            NaN
# 7             1.0             NaN          NaN           NaN            1.0
# 8             NaN             NaN          NaN           NaN            NaN
# 9             NaN             NaN          NaN           NaN            NaN
# 10            NaN             1.0          NaN           NaN            2.0
# 11            NaN             NaN          2.0           NaN            NaN
# 12            1.0             1.0          NaN           3.0            NaN
# 13            NaN             NaN          NaN           NaN            NaN
# 14            NaN             2.0          NaN           NaN            1.0
# 15            NaN             NaN          NaN           NaN            NaN
# 16            1.0             1.0          NaN           NaN            3.0
# 17            NaN             NaN          NaN           NaN            NaN
# 18            NaN             NaN          NaN           NaN            NaN
# 19            NaN             NaN          NaN           NaN            NaN
# 20            NaN             NaN          NaN           NaN            NaN
# 21            1.0             NaN          NaN           3.0            1.0
# 22            NaN             NaN          NaN           NaN            NaN
# 23            NaN             NaN          NaN           NaN            NaN
# 24            1.0             NaN          2.0           NaN            3.0
# 25            NaN             2.0          NaN           1.0            6.0
# 26            NaN             NaN          NaN           NaN            NaN
# 27            NaN             NaN          NaN           NaN            NaN
# 28            1.0             NaN          NaN           NaN            2.0
# 29            NaN             NaN          NaN           NaN            NaN
# 30            1.0             1.0          NaN           NaN            2.0
# 31            NaN             NaN          NaN           NaN            1.0
# 32            NaN             2.0          NaN           NaN            1.0
# 33            NaN             1.0          NaN           NaN            2.0
# 34            NaN             1.0          NaN           NaN            1.0
# 35            NaN             NaN          NaN           NaN            NaN
# 36            NaN             NaN          NaN           NaN            NaN
# 37            1.0             NaN          NaN           NaN            NaN
# 38            1.0             NaN          NaN           NaN            1.0
# 39            NaN             NaN          NaN           1.0            NaN
# 40            1.0             NaN          1.0           NaN            NaN
# 41            NaN             NaN          NaN           NaN            NaN
# 42            1.0             1.0          NaN           NaN            2.0
# 43            NaN             1.0          1.0           2.0            1.0
# 44            NaN             NaN          NaN           NaN            NaN
# 45            NaN             NaN          NaN           NaN            NaN
# 46            NaN             NaN          NaN           NaN            NaN
# 47            NaN             NaN          NaN           NaN            NaN
# 48            NaN             NaN          NaN           1.0            NaN
# 49            NaN             NaN          NaN           NaN            NaN
# 50            NaN             NaN          NaN           NaN            NaN
# 51            NaN             NaN          NaN           1.0            NaN
# 52            NaN             NaN          NaN           NaN            NaN
# 53            NaN             NaN          NaN           NaN            NaN
# 54            NaN             NaN          NaN           NaN            NaN
# 55            NaN             NaN          NaN           NaN            NaN
# 56            NaN             NaN          NaN           NaN            NaN
# 57            NaN             NaN          NaN           1.0            NaN
# 58            NaN             NaN          NaN           NaN            NaN
# 59            NaN             NaN          NaN           NaN            NaN
# 60            NaN             NaN          NaN           1.0            NaN
#
#     away_points  away_assists  away_fouls  away_steals  away_3pt_made  \
# 0          11.0           4.0         3.0          2.0            1.0
# 1           NaN           NaN         NaN          NaN            NaN
# 2           3.0           NaN         NaN          1.0            NaN
# 3           NaN           NaN         NaN          NaN            NaN
# 4           3.0           1.0         NaN          NaN            NaN
# 5           NaN           NaN         NaN          NaN            NaN
# 6           NaN           NaN         NaN          NaN            NaN
# 7           2.0           1.0         NaN          NaN            NaN
# 8           NaN           NaN         NaN          NaN            NaN
# 9           NaN           NaN         NaN          NaN            NaN
# 10          7.0           2.0         1.0          1.0            1.0
# 11          NaN           NaN         1.0          NaN            NaN
# 12          1.0           NaN         1.0          1.0            NaN
# 13          NaN           NaN         NaN          NaN            NaN
# 14          5.0           1.0         2.0          NaN            1.0
# 15          NaN           NaN         NaN          NaN            NaN
# 16          9.0           4.0         1.0          1.0            1.0
# 17          NaN           NaN         NaN          NaN            NaN
# 18          NaN           NaN         NaN          NaN            NaN
# 19          NaN           NaN         NaN          NaN            NaN
# 20          NaN           NaN         NaN          NaN            NaN
# 21          2.0           NaN         2.0          NaN            NaN
# 22          NaN           NaN         NaN          NaN            NaN
# 23          NaN           NaN         NaN          NaN            NaN
# 24          7.0           2.0         NaN          NaN            NaN
# 25         16.0           2.0         3.0          NaN            NaN
# 26          NaN           NaN         NaN          NaN            NaN
# 27          1.0           NaN         NaN          NaN            NaN
# 28         10.0           3.0         NaN          NaN            2.0
# 29          NaN           NaN         NaN          NaN            NaN
# 30          4.0           2.0         NaN          NaN            NaN
# 31          2.0           1.0         NaN          NaN            NaN
# 32          2.0           NaN         NaN          1.0            NaN
# 33          7.0           NaN         1.0          1.0            NaN
# 34          3.0           1.0         NaN          1.0            NaN
# 35          NaN           NaN         NaN          NaN            NaN
# 36          NaN           NaN         NaN          NaN            NaN
# 37          1.0           NaN         NaN          NaN            NaN
# 38          6.0           1.0         1.0          NaN            1.0
# 39          3.0           1.0         NaN          NaN            1.0
# 40          NaN           NaN         NaN          NaN            NaN
# 41          1.0           NaN         NaN          NaN            NaN
# 42          5.0           NaN         NaN          NaN            NaN
# 43          3.0           1.0         1.0          1.0            NaN
# 44          NaN           NaN         NaN          NaN            NaN
# 45          NaN           NaN         1.0          NaN            NaN
# 46          NaN           NaN         NaN          NaN            NaN
# 47          NaN           NaN         NaN          NaN            NaN
# 48          NaN           NaN         NaN          NaN            NaN
# 49          NaN           NaN         NaN          NaN            NaN
# 50          NaN           NaN         NaN          NaN            NaN
# 51          2.0           NaN         NaN          NaN            NaN
# 52          NaN           NaN         NaN          NaN            NaN
# 53          NaN           NaN         NaN          NaN            NaN
# 54          NaN           NaN         NaN          NaN            NaN
# 55          NaN           NaN         NaN          NaN            NaN
# 56          NaN           NaN         NaN          NaN            NaN
# 57          NaN           NaN         NaN          NaN            NaN
# 58          NaN           NaN         NaN          NaN            NaN
# 59          NaN           NaN         NaN          NaN            NaN
# 60          NaN           NaN         NaN          NaN            NaN
#
#     away_def_rebounds  away_turnovers  away_off_rebounds  away_blocks  \
# 0                 2.0             1.0                2.0          NaN
# 1                 NaN             NaN                NaN          1.0
# 2                 NaN             NaN                NaN          NaN
# 3                 NaN             NaN                NaN          NaN
# 4                 1.0             NaN                NaN          1.0
# 5                 NaN             NaN                NaN          NaN
# 6                 NaN             NaN                NaN          NaN
# 7                 2.0             1.0                NaN          NaN
# 8                 NaN             NaN                NaN          NaN
# 9                 NaN             NaN                NaN          NaN
# 10                1.0             NaN                1.0          NaN
# 11                1.0             2.0                NaN          NaN
# 12                NaN             NaN                NaN          NaN
# 13                NaN             NaN                NaN          1.0
# 14                1.0             1.0                NaN          NaN
# 15                NaN             NaN                NaN          NaN
# 16                3.0             NaN                NaN          2.0
# 17                NaN             NaN                NaN          NaN
# 18                NaN             NaN                NaN          NaN
# 19                NaN             NaN                NaN          NaN
# 20                NaN             NaN                NaN          NaN
# 21                1.0             NaN                NaN          NaN
# 22                NaN             NaN                NaN          NaN
# 23                NaN             NaN                NaN          NaN
# 24                2.0             2.0                NaN          NaN
# 25                4.0             1.0                NaN          NaN
# 26                NaN             NaN                NaN          NaN
# 27                1.0             NaN                NaN          NaN
# 28                3.0             NaN                NaN          1.0
# 29                NaN             NaN                NaN          NaN
# 30                NaN             NaN                NaN          NaN
# 31                1.0             NaN                NaN          NaN
# 32                NaN             NaN                NaN          NaN
# 33                1.0             NaN                NaN          1.0
# 34                NaN             NaN                NaN          NaN
# 35                NaN             NaN                NaN          NaN
# 36                NaN             NaN                NaN          NaN
# 37                1.0             NaN                NaN          NaN
# 38                1.0             NaN                NaN          NaN
# 39                1.0             NaN                NaN          1.0
# 40                NaN             1.0                NaN          NaN
# 41                NaN             NaN                NaN          NaN
# 42                1.0             NaN                2.0          NaN
# 43                2.0             2.0                NaN          1.0
# 44                NaN             NaN                NaN          NaN
# 45                NaN             NaN                NaN          NaN
# 46                NaN             NaN                NaN          NaN
# 47                NaN             NaN                NaN          NaN
# 48                NaN             NaN                NaN          NaN
# 49                NaN             NaN                NaN          NaN
# 50                NaN             NaN                NaN          NaN
# 51                NaN             NaN                NaN          NaN
# 52                NaN             NaN                NaN          NaN
# 53                NaN             NaN                NaN          NaN
# 54                NaN             NaN                NaN          NaN
# 55                NaN             NaN                NaN          NaN
# 56                NaN             NaN                NaN          NaN
# 57                NaN             NaN                NaN          NaN
# 58                NaN             NaN                NaN          NaN
# 59                NaN             NaN                NaN          NaN
# 60                NaN             NaN                NaN          NaN
#
#     home_fouls  away_ft_made  home_blocks
# 0          NaN           NaN          NaN
# 1          NaN           NaN          NaN
# 2          1.0           1.0          NaN
# 3          NaN           NaN          NaN
# 4          NaN           1.0          NaN
# 5          NaN           NaN          NaN
# 6          NaN           NaN          NaN
# 7          1.0           NaN          NaN
# 8          NaN           NaN          NaN
# 9          NaN           NaN          NaN
# 10         1.0           NaN          NaN
# 11         NaN           NaN          NaN
# 12         1.0           1.0          3.0
# 13         NaN           NaN          NaN
# 14         NaN           NaN          NaN
# 15         NaN           NaN          NaN
# 16         NaN           NaN          NaN
# 17         NaN           NaN          NaN
# 18         NaN           NaN          NaN
# 19         NaN           NaN          NaN
# 20         NaN           NaN          NaN
# 21         NaN           NaN          NaN
# 22         NaN           NaN          NaN
# 23         NaN           NaN          NaN
# 24         2.0           1.0          NaN
# 25         3.0           4.0          NaN
# 26         NaN           NaN          NaN
# 27         1.0           1.0          NaN
# 28         NaN           NaN          NaN
# 29         NaN           NaN          NaN
# 30         NaN           NaN          NaN
# 31         NaN           NaN          NaN
# 32         NaN           NaN          NaN
# 33         2.0           3.0          NaN
# 34         NaN           1.0          NaN
# 35         NaN           NaN          NaN
# 36         NaN           NaN          NaN
# 37         1.0           1.0          NaN
# 38         NaN           1.0          NaN
# 39         NaN           NaN          NaN
# 40         NaN           NaN          NaN
# 41         1.0           1.0          NaN
# 42         1.0           1.0          1.0
# 43         NaN           1.0          NaN
# 44         NaN           NaN          NaN
# 45         NaN           NaN          1.0
# 46         NaN           NaN          NaN
# 47         NaN           NaN          NaN
# 48         NaN           NaN          NaN
# 49         NaN           NaN          NaN
# 50         NaN           NaN          NaN
# 51         1.0           2.0          NaN
# 52         NaN           NaN          NaN
# 53         NaN           NaN          NaN
# 54         NaN           NaN          NaN
# 55         NaN           NaN          NaN
# 56         NaN           NaN          NaN
# 57         NaN           NaN          NaN
# 58         NaN           NaN          NaN
# 59         NaN           NaN          NaN
# 60         NaN           NaN          NaN

# %%
def time_str_to_sec(t):
    """Convert 'M:SS' string to total seconds."""
    if isinstance(t, str):
        m, s = map(int, t.strip().split(":"))
        return m * 60 + s
    return 0  # handle missing or bad values

def compute_duration(row):
    start_sec = time_str_to_sec(row['start_time'])
    end_sec = time_str_to_sec(row['end_time'])

    start_period = row['period']
    end_period = row['period']  # assume same period unless time increases

    # If clock resets (e.g. start_time = 0:03, end_time = 10:39), period must've changed
    if time_str_to_sec(row['end_time']) > time_str_to_sec(row['start_time']):
        end_period = start_period + 1

    # Duration across possible multiple periods
    period_diff = end_period - start_period
    duration = start_sec + period_diff * 720 - end_sec

    return duration

# %%
lineup_vs_lineup_df['duration'] = lineup_vs_lineup_df.apply(compute_duration, axis=1)

# %%
non_stat_cols = ['home_lineup', 'away_lineup', 'start_time', 'end_time', 'period', 'start_event', 'end_event', 'duration']
stat_cols = [col for col in lineup_vs_lineup_df.columns if col not in non_stat_cols]
lineup_vs_lineup_df['non_nan_stats'] = lineup_vs_lineup_df[stat_cols].notna().sum(axis=1)

# %%
# Filter: remove short or empty segments
lu_vs_lu_filtered = lineup_vs_lineup_df[
    (lineup_vs_lineup_df['duration'] >= 25) |   # at least 24 seconds
    (lineup_vs_lineup_df['non_nan_stats'] >= 3)  # at least 2 non-NaN stats
].copy()
lu_vs_lu_filtered = lu_vs_lu_filtered.fillna(0)

# %%
total_home_points = lineup_vs_lineup_df['home_points'].sum()
total_away_points = lineup_vs_lineup_df['away_points'].sum()
print(f"The total home points is: {total_home_points}")
print(f"The total away points is: {total_away_points}")
# Out:
# The total home points is: 121.0
# The total away points is: 116.0

# %% [markdown]
# # player_stats_df
# **Player stats per segment**<br>
# Each row:
# - Represents a single player's contributions in a specific segment
# - Includes which lineups they were in
# - Stats across that segment only

# %%
player_stats_data = []

for seg in lineup_segments:
    for player_name, stats in seg['player_stats'].items():
        row = {
            'player': player_name,
            'period': seg['period'],
            'start_event': seg['start_event'],
            'end_event': seg['end_event'],
            'start_time': seg['start_time'],
            'end_time': seg['end_time'],
            'home_lineup': seg['home_lineup'],
            'away_lineup': seg['away_lineup'],
        }

        # Flatten stat values
        for stat, value in stats.items():
            row[stat] = value

        player_stats_data.append(row)

player_stats_df = pd.DataFrame(player_stats_data)

# %%
player_stats_df.head(10)
# Out:
#                player  period  start_event  end_event start_time end_time  \
# 0        Myles Turner       1            2         69      12:00     6:43
# 1   Tyrese Haliburton       1            2         69      12:00     6:43
# 2         Bruce Brown       1            2         69      12:00     6:43
# 3  Bennedict Mathurin       1            2         69      12:00     6:43
# 4    Donovan Mitchell       1            2         69      12:00     6:43
# 5      Darius Garland       1            2         69      12:00     6:43
# 6           Max Strus       1            2         69      12:00     6:43
# 7       Jarrett Allen       1            2         69      12:00     6:43
# 8          Obi Toppin       1            2         69      12:00     6:43
# 9         Evan Mobley       1            2         69      12:00     6:43
#
#                                          home_lineup  \
# 0  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 1  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 2  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 3  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 4  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 5  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 6  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 7  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 8  (Bennedict Mathurin, Bruce Brown, Myles Turner...
# 9  (Bennedict Mathurin, Bruce Brown, Myles Turner...
#
#                                          away_lineup  2pt_made  points  \
# 0  (Darius Garland, Donovan Mitchell, Evan Mobley...       1.0     7.0
# 1  (Darius Garland, Donovan Mitchell, Evan Mobley...       NaN     NaN
# 2  (Darius Garland, Donovan Mitchell, Evan Mobley...       2.0     7.0
# 3  (Darius Garland, Donovan Mitchell, Evan Mobley...       NaN     3.0
# 4  (Darius Garland, Donovan Mitchell, Evan Mobley...       2.0     7.0
# 5  (Darius Garland, Donovan Mitchell, Evan Mobley...       NaN     NaN
# 6  (Darius Garland, Donovan Mitchell, Evan Mobley...       NaN     NaN
# 7  (Darius Garland, Donovan Mitchell, Evan Mobley...       2.0     4.0
# 8  (Darius Garland, Donovan Mitchell, Evan Mobley...       NaN     NaN
# 9  (Darius Garland, Donovan Mitchell, Evan Mobley...       NaN     NaN
#
#    def_rebounds  turnovers  3pt_made  steals  ft_made  assists  off_rebounds  \
# 0           2.0        1.0       1.0     1.0      2.0      NaN           NaN
# 1           1.0        1.0       NaN     NaN      NaN      1.0           NaN
# 2           2.0        NaN       1.0     NaN      NaN      1.0           1.0
# 3           NaN        NaN       1.0     NaN      NaN      2.0           1.0
# 4           NaN        1.0       1.0     NaN      NaN      NaN           NaN
# 5           NaN        NaN       NaN     NaN      NaN      4.0           NaN
# 6           1.0        NaN       NaN     NaN      NaN      NaN           NaN
# 7           1.0        NaN       NaN     1.0      NaN      NaN           1.0
# 8           NaN        NaN       NaN     NaN      NaN      1.0           NaN
# 9           NaN        NaN       NaN     1.0      NaN      NaN           1.0
#
#    fouls
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    1.0
# 6    1.0
# 7    1.0
# 8    NaN
# 9    NaN

# %%
player_stats_filtered_df = player_stats_df.merge(
    lu_vs_lu_filtered[['start_event', 'end_event', 'period', 'duration']],
    on=['start_event', 'end_event', 'period'],
    how='inner'
)

# %%
player_stats_filtered_df = player_stats_filtered_df.fillna(0)
